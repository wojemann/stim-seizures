# %%
import numpy as np
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt
from ieeg.auth import Session
from scipy import signal as sig
import os
from os.path import join as ospj
from os.path import exists as ospe
import pathlib

# %%
import sys
sys.path.append('/users/wojemann/iEEG_processing')
from pioneer import Pioneer

# %%
with open('config.json','r') as f:
    config = json.load(f)

# %%
ptList = config['patients']
ptList
# Out:
# ['HUP211_phaseII',
#  'HUP212_phaseII',
#  'HUP213_phaseII',
#  'HUP214_phaseII',
#  'HUP216_phaseII',
#  'HUP218_phaseII',
#  'HUP223_phaseII',
#  'HUP224_phaseII',
#  'HUP225_phaseII',
#  'HUP228_phaseII',
#  'HUP229_phaseII',
#  'HUP230_phaseII',
#  'HUP235_phaseII',
#  'HUP238_phaseII',
#  'HUP246_phaseII',
#  'HUP247_phaseII']

# %%
display(config['paths'])
raw_datapath = config['paths']['RAW_DATA']
usr = config['paths']['iEEG_USR']
pwd = config['paths']['iEEG_PWD']
ignore_list = config['ignore']
# Out:
# {'RAW_DATA': '/users/wojemann/stim-seizures/RAW_DATA',
#  'iEEG_USR': 'wojemann',
#  'iEEG_PWD': '/users/wojemann/woj_ieeglogin.bin'}

# %%
wagon = Pioneer(usr,pwd,ptList[1])
display(wagon.ID)
# Out:
# 'HUP212_phaseII'

# %%
for i,pt in enumerate(ptList):
    save_path = ospj(raw_datapath,pt)
    if ospe(save_path):
        continue
    if not ospe(save_path):
        os.makedirs(save_path)
    if ignore_list[i]:
        continue
    wagon = Pioneer(usr,pwd,pt)
    wagon.pull_annotations()
    wagon.filter_seizure_annotations()
    wagon.seizure_annotations.to_csv(ospj(save_path,'seizure_annotations.csv'))
    stim = False
    for _,row in wagon.seizure_annotations.rowiter():
# Out:
# got 3 annotations on call # 1 covering 185095588249 usec to 185156564276 usec
# Filtered      10.00% of all annotations
# got 100 annotations on call # 1 covering 78122185209 usec to 447161111585 usec
# got 100 annotations on call # 2 covering 447990693617 usec to 614647121216 usec
# got 100 annotations on call # 3 covering 614700777466 usec to 660257408088 usec
# got 100 annotations on call # 4 covering 660265902229 usec to 662061730354 usec
# got 55 annotations on call # 5 covering 662088406135 usec to 717732786018 usec
# Filtered       8.95% of all annotations
# /users/wojemann/iEEG_processing/pioneer.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_annotations['IEEG Time'] = t_sec
# got 100 annotations on call # 1 covering 1133775390 usec to 114775418891 usec
# got 100 annotations on call # 2 covering 114775501899 usec to 249146627179 usec
# got 100 annotations on call # 3 covering 252068164288 usec to 431971487131 usec
# got 100 annotations on call # 4 covering 434333090615 usec to 450671095497 usec
# got 46 annotations on call # 5 covering 450704038857 usec to 486452957802 usec
# Filtered       9.01% of all annotations
# got 100 annotations on call # 1 covering 1102048828 usec to 156666918813 usec
# got 100 annotations on call # 2 covering 158839224477 usec to 277724202553 usec
# got 100 annotations on call # 3 covering 277726689858 usec to 473180865152 usec
# got 53 annotations on call # 4 covering 473205042886 usec to 522108813780 usec
# Filtered       9.04% of all annotations
# got 100 annotations on call # 1 covering 2847001953 usec to 204007098027 usec
# got 100 annotations on call # 2 covering 207647993535 usec to 312536073465 usec
# got 100 annotations on call # 3 covering 312544754129 usec to 408584005088 usec
# got 65 annotations on call # 4 covering 408585490439 usec to 604914775367 usec
# Filtered       8.55% of all annotations
# got 100 annotations on call # 1 covering 146714843 usec to 51362779296 usec
# got 100 annotations on call # 2 covering 53170522461 usec to 83749286818 usec
# got 100 annotations on call # 3 covering 83749286818 usec to 166993223303 usec
# got 100 annotations on call # 4 covering 166993223303 usec to 227989009435 usec
# got 100 annotations on call # 5 covering 233063358013 usec to 259443518169 usec
# got 100 annotations on call # 6 covering 259443518169 usec to 272005142192 usec
# got 100 annotations on call # 7 covering 272006911724 usec to 286788614849 usec
# got 100 annotations on call # 8 covering 286788614849 usec to 301936297466 usec
# got 100 annotations on call # 9 covering 301936297466 usec to 307462446880 usec
# got 100 annotations on call # 10 covering 307462446880 usec to 350276836292 usec
# got 100 annotations on call # 11 covering 350277082386 usec to 372009058949 usec
# got 100 annotations on call # 12 covering 372013181019 usec to 450221954642 usec
# got 100 annotations on call # 13 covering 450225962455 usec to 535032272536 usec
# got 14 annotations on call # 14 covering 541542981521 usec to 587349316063 usec
# Filtered       7.75% of all annotations
# got 100 annotations on call # 1 covering 9186292125 usec to 102188472478 usec
# got 100 annotations on call # 2 covering 102203052556 usec to 133115889470 usec
# got 100 annotations on call # 3 covering 133191363103 usec to 222983634817 usec
# got 100 annotations on call # 4 covering 222998496145 usec to 257084414172 usec
# got 100 annotations on call # 5 covering 257345149524 usec to 293302470813 usec
# got 100 annotations on call # 6 covering 293303384875 usec to 406661048146 usec
# got 100 annotations on call # 7 covering 408895809865 usec to 444247507392 usec
# got 100 annotations on call # 8 covering 444252158759 usec to 515050142413 usec
# got 78 annotations on call # 9 covering 515095452960 usec to 683296522301 usec
# Filtered       9.19% of all annotations
# got 100 annotations on call # 1 covering 1707461914 usec to 86035700595 usec
# got 100 annotations on call # 2 covering 86620269931 usec to 280099291698 usec
# got 100 annotations on call # 3 covering 280124173534 usec to 337866707757 usec
# got 100 annotations on call # 4 covering 337872806390 usec to 433228048439 usec
# got 100 annotations on call # 5 covering 433254042580 usec to 550297636943 usec
# got 14 annotations on call # 6 covering 550342953350 usec to 612733120179 usec
# Filtered       8.64% of all annotations

# %%
wagon.pull_annotations()
# Out:
# got 100 annotations on call # 1 covering 78122185209 usec to 447161111585 usec
# got 100 annotations on call # 2 covering 447990693617 usec to 614647121216 usec
# got 100 annotations on call # 3 covering 614700777466 usec to 660257408088 usec
# got 100 annotations on call # 4 covering 660265902229 usec to 662061730354 usec
# got 55 annotations on call # 5 covering 662088406135 usec to 717732786018 usec

# %%
wagon.filter_seizure_annotations()
# Out:
# Filtered       8.95% of all annotations
# /users/wojemann/iEEG_processing/pioneer.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_annotations['IEEG Time'] = t_sec

# %%
# wagon.annotations.to_csv('example_annotations.csv')
wagon.seizure_annotations
# Out:
#                            Duration  \
# Time
# 1970-01-01 21:42:02.185209   0 days
# 1970-01-01 23:30:05.083647   0 days
# 1970-01-02 01:53:58.610991   0 days
# 1970-01-02 03:32:56.624663   0 days
# 1970-01-02 05:23:58.602202   0 days
# 1970-01-02 07:36:09.667631   0 days
# 1970-01-02 09:09:48.647123   0 days
# 1970-01-02 10:58:50.580960   0 days
# 1970-01-02 11:03:39.708890   0 days
# 1970-01-02 13:04:42.972561   0 days
# 1970-01-02 14:00:09.029202   0 days
# 1970-01-03 14:49:25.231401   0 days
# 1970-01-03 20:18:42.483354   0 days
# 1970-01-03 21:47:35.869096   0 days
# 1970-01-04 00:11:05.696245   0 days
# 1970-01-04 03:13:58.867143   0 days
# 1970-01-04 07:12:47.939409   0 days
# 1970-01-04 13:48:27.963890   0 days
# 1970-01-04 20:21:09.102562   0 days
# 1970-01-05 13:31:02.800062   0 days
# 1970-01-05 16:54:13.689710   0 days
# 1970-01-06 13:41:57.491486   0 days
# 1970-01-06 18:52:28.035431   0 days
# 1970-01-06 23:34:21.714142   0 days
# 1970-01-06 23:37:07.955353   0 days
# 1970-01-06 23:39:15.148712   0 days
# 1970-01-08 02:39:44.653443   0 days
# 1970-01-08 02:44:05.706177   0 days
# 1970-01-08 02:45:14.980591   0 days
# 1970-01-08 04:46:58.475708   0 days
# 1970-01-08 05:21:16.721802   0 days
# 1970-01-08 07:58:15.766724   0 days
# 1970-01-08 12:54:04.150276   0 days
# 1970-01-08 15:03:56.816291   0 days
# 1970-01-08 15:42:39.218635   0 days
# 1970-01-08 15:42:46.870979   0 days
# 1970-01-08 15:43:01.794807   0 days
# 1970-01-08 15:43:16.122932   0 days
# 1970-01-08 15:43:30.314338   0 days
# 1970-01-08 15:46:26.747932   0 days
# 1970-01-08 21:21:00.399299   0 days
# 1970-01-08 21:25:21.673713   0 days
# 1970-01-08 22:38:49.887580   0 days
# 1970-01-08 22:43:19.636604   0 days
# 1970-01-08 22:43:31.822151   0 days
# 1970-01-09 02:55:49.445197   0 days
# 1970-01-09 03:00:36.671760   0 days
# 1970-01-09 03:00:40.804572   0 days
#
#                                                                   Description  \
# Time
# 1970-01-01 21:42:02.185209                                         interictal
# 1970-01-01 23:30:05.083647                                      Patient Event
# 1970-01-02 01:53:58.610991                                         INTERICTAL
# 1970-01-02 03:32:56.624663                                         INTERICTAL
# 1970-01-02 05:23:58.602202                                         INTERICTAL
# 1970-01-02 07:36:09.667631                                         INTERICTAL
# 1970-01-02 09:09:48.647123                                         INTERICTAL
# 1970-01-02 10:58:50.580960                                           EVENT #1
# 1970-01-02 11:03:39.708890                                      Patient Event
# 1970-01-02 13:04:42.972561                                      Patient Event
# 1970-01-02 14:00:09.029202                                         interictal
# 1970-01-03 14:49:25.231401                                         INTERICTAL
# 1970-01-03 20:18:42.483354                                      Patient Event
# 1970-01-03 21:47:35.869096                                         interictal
# 1970-01-04 00:11:05.696245                                      Patient Event
# 1970-01-04 03:13:58.867143                          interictal; LH,LI slowing
# 1970-01-04 07:12:47.939409                                  interictal, sleep
# 1970-01-04 13:48:27.963890                                      Patient Event
# 1970-01-04 20:21:09.102562                                      Patient Event
# 1970-01-05 13:31:02.800062                                      Patient Event
# 1970-01-05 16:54:13.689710                no clear interictal discharges seen
# 1970-01-06 13:41:57.491486                                      Patient Event
# 1970-01-06 18:52:28.035431  NOT EVENTS: intermittent twichings of legs/han...
# 1970-01-06 23:34:21.714142                                              EVENT
# 1970-01-06 23:37:07.955353                                      Patient Event
# 1970-01-06 23:39:15.148712                                      ictal testing
# 1970-01-08 02:39:44.653443                                           EVENT #1
# 1970-01-08 02:44:05.706177                                              EVENT
# 1970-01-08 02:45:14.980591                                      Patient Event
# 1970-01-08 04:46:58.475708                                      Patient Event
# 1970-01-08 05:21:16.721802                                         INTERICTAL
# 1970-01-08 07:58:15.766724                                         INTERICTAL
# 1970-01-08 12:54:04.150276                                      Patient Event
# 1970-01-08 15:03:56.816291                                      CORTICAL STIM
# 1970-01-08 15:42:39.218635                                              ictal
# 1970-01-08 15:42:46.870979                                      ictal disrupt
# 1970-01-08 15:43:01.794807                                      ictal disrupt
# 1970-01-08 15:43:16.122932                                     ictal disruupt
# 1970-01-08 15:43:30.314338                                      ictal disrupt
# 1970-01-08 15:46:26.747932                                      ictal disrupt
# 1970-01-08 21:21:00.399299                                           EVENT #1
# 1970-01-08 21:25:21.673713                                      Patient Event
# 1970-01-08 22:38:49.887580                                           EVENT #2
# 1970-01-08 22:43:19.636604                                      Patient Event
# 1970-01-08 22:43:31.822151                                              event
# 1970-01-09 02:55:49.445197                                           EVENT #3
# 1970-01-09 03:00:36.671760                                      Patient Event
# 1970-01-09 03:00:40.804572                              event/ crying in pain
#
#                                 IEEG Time
# Time
# 1970-01-01 21:42:02.185209   78122.185209
# 1970-01-01 23:30:05.083647   84605.083647
# 1970-01-02 01:53:58.610991   93238.610991
# 1970-01-02 03:32:56.624663   99176.624663
# 1970-01-02 05:23:58.602202  105838.602202
# 1970-01-02 07:36:09.667631  113769.667631
# 1970-01-02 09:09:48.647123  119388.647123
# 1970-01-02 10:58:50.580960  125930.580960
# 1970-01-02 11:03:39.708890  126219.708890
# 1970-01-02 13:04:42.972561  133482.972561
# 1970-01-02 14:00:09.029202  136809.029202
# 1970-01-03 14:49:25.231401  226165.231401
# 1970-01-03 20:18:42.483354  245922.483354
# 1970-01-03 21:47:35.869096  251255.869096
# 1970-01-04 00:11:05.696245  259865.696245
# 1970-01-04 03:13:58.867143  270838.867143
# 1970-01-04 07:12:47.939409  285167.939409
# 1970-01-04 13:48:27.963890  308907.963890
# 1970-01-04 20:21:09.102562  332469.102562
# 1970-01-05 13:31:02.800062  394262.800062
# 1970-01-05 16:54:13.689710  406453.689710
# 1970-01-06 13:41:57.491486  481317.491486
# 1970-01-06 18:52:28.035431  499948.035431
# 1970-01-06 23:34:21.714142  516861.714142
# 1970-01-06 23:37:07.955353  517027.955353
# 1970-01-06 23:39:15.148712  517155.148712
# 1970-01-08 02:39:44.653443  614384.653443
# 1970-01-08 02:44:05.706177  614645.706177
# 1970-01-08 02:45:14.980591  614714.980591
# 1970-01-08 04:46:58.475708  622018.475708
# 1970-01-08 05:21:16.721802  624076.721802
# 1970-01-08 07:58:15.766724  633495.766724
# 1970-01-08 12:54:04.150276  651244.150276
# 1970-01-08 15:03:56.816291  659036.816291
# 1970-01-08 15:42:39.218635  661359.218635
# 1970-01-08 15:42:46.870979  661366.870979
# 1970-01-08 15:43:01.794807  661381.794807
# 1970-01-08 15:43:16.122932  661396.122932
# 1970-01-08 15:43:30.314338  661410.314338
# 1970-01-08 15:46:26.747932  661586.747932
# 1970-01-08 21:21:00.399299  681660.399299
# 1970-01-08 21:25:21.673713  681921.673713
# 1970-01-08 22:38:49.887580  686329.887580
# 1970-01-08 22:43:19.636604  686599.636604
# 1970-01-08 22:43:31.822151  686611.822151
# 1970-01-09 02:55:49.445197  701749.445197
# 1970-01-09 03:00:36.671760  702036.671760
# 1970-01-09 03:00:40.804572  702040.804572

# %% [markdown]
# #### Goal of next section is to make a csv containing all of the seizure times for each of these patients. The csv should contain HUPID, EEC, UEO, flag for stim or not,

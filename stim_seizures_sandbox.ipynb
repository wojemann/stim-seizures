# %%
import pandas as pd
import json

# %%
metadata = pd.read_csv('metadata.csv')
# (metadata.cceps_hfs_seizure == 1) | 
metadata = metadata[(metadata.cceps_run1_sz == 1)]
metadata.loc[:,'ieeg_id'] = 'HUP' + metadata.hupsubjno.apply(str) + '_phaseII'
metadata.loc[:,'ccep_id'] = 'HUP' + metadata.hupsubjno.apply(str) + '_CCEP'
len(metadata)
metadata.head()
# Out:
#     record_id  hupsubjno  ageatieegimplant ieeg_ictal_onset_electrodes  \
# 10        617        224              42.0               RB2, RB3, RC2
# 11        700        225              33.0                    RT4, RT5
# 13        835        229              40.0          LB1, LB2, LA1, LA2
# 14        808        230              51.0     LC1, LC2, LC3, LB1, LB2
# 16        796        235              24.0          LC1, LC2, LB2, LB3
#
#     ieeg_ictal_onset_anat_lat ieeg_ictal_onset_anat_spec  \
# 10                        2.0                hippocampus
# 11                        2.0         temporal neocortex
# 13                        1.0            mesial temporal
# 14                        1.0                hippocampus
# 16                        1.0      hippocampal tail/body
#
#     cceps_run1_home_meds  cceps_run1_pulsewidth  cceps_run1_sz  \
# 10                     0                    300              1
# 11                     0                    300              1
# 13                     1                    300              1
# 14                     1                    500              1
# 16                     1                    500              1
#
#    cceps_run1_szelecs                          cceps_run1_soz_electrodes  \
# 10                LB1  LB1, LB2, LB3, LB4, LB5, LC1, LC2, LC3, LC4, L...
# 11                RC1                                 RB1, RB2, RB3, RB4
# 13                LG1                            LB1, LB2, LC1, LC2, LC3
# 14                LB5                                 LC1, LC2, LC3, LC4
# 16                LA4  LA1, LA2, LA3, LB1, LB2, LB3, LC1, LC2, LC3, L...
#
#     cceps_run1_seizure_typical  cceps_hfs_done  cceps_hfs_seizure  \
# 10                         2.0             2.0                NaN
# 11                         1.0             1.0                2.0
# 13                         1.0             2.0                NaN
# 14                         3.0             2.0                NaN
# 16                         1.0             1.0                1.0
#
#    cceps_hfs_stim_elec_sz  cceps_hfs_sz_typical  Unnamed: 16         ieeg_id  \
# 10                    NaN                   NaN          NaN  HUP224_phaseII
# 11                    NaN                   NaN          NaN  HUP225_phaseII
# 13                    NaN                   NaN          NaN  HUP229_phaseII
# 14                    NaN                   NaN          NaN  HUP230_phaseII
# 16                    LA1                   1.0          NaN  HUP235_phaseII
#
#         ccep_id
# 10  HUP224_CCEP
# 11  HUP225_CCEP
# 13  HUP229_CCEP
# 14  HUP230_CCEP
# 16  HUP235_CCEP

# %%
metadata.ieeg_id
# Out:
# 10    HUP224_phaseII
# 11    HUP225_phaseII
# 13    HUP229_phaseII
# 14    HUP230_phaseII
# 16    HUP235_phaseII
# 18    HUP238_phaseII
# 23    HUP246_phaseII
# 24    HUP247_phaseII
# 25    HUP249_phaseII
# 26    HUP250_phaseII
# 27    HUP253_phaseII
# Name: ieeg_id, dtype: object

# %%
metadata
# Out:
#     record_id  hupsubjno  ageatieegimplant  \
# 0         650        211              23.0
# 1         651        212              55.0
# 2         649        213              21.0
# 3         652        214              40.0
# 4         658        216              21.0
# 5         677        218              49.0
# 9         785        223              46.0
# 10        617        224              42.0
# 11        700        225              33.0
# 12        676        228              29.0
# 13        835        229              40.0
# 14        808        230              51.0
# 16        796        235              24.0
# 18        861        238              35.0
# 23        893        246              52.0
# 24        921        247               NaN
# 25        876        249               NaN
# 26        534        250              31.0
# 27        864        253               NaN
#
#                           ieeg_ictal_onset_electrodes  \
# 0   LC1, LC2, LI1, LI2, LI3, LI4, LB1, LB2, LC1, L...
# 1                                                 NaN
# 2   LA1, LA2, LA3, LA4, LA5, LH3, LH4, LH5, LH6, L...
# 3                                  LB1, LB2, RB1, RB2
# 4                                  LC1, LC2, LB1, LB2
# 5              RA1, RA2, RB2, RB3, RB4, RD1, RD2, RD4
# 9                                            LB3, LC3
# 10                                      RB2, RB3, RC2
# 11                                           RT4, RT5
# 12                                                NaN
# 13                                 LB1, LB2, LA1, LA2
# 14                            LC1, LC2, LC3, LB1, LB2
# 16                                 LC1, LC2, LB2, LB3
# 18                       LB1, LB2, LB3, LC1, LC2, LC3
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#     ieeg_ictal_onset_anat_lat ieeg_ictal_onset_anat_spec  \
# 0                         3.0            mesial temporal
# 1                         NaN                        NaN
# 2                         1.0                 multifocal
# 3                         3.0            Mesial temporal
# 4                         1.0                     insula
# 5                         2.0            mesial temporal
# 9                         1.0            mesial temporal
# 10                        2.0                hippocampus
# 11                        2.0         temporal neocortex
# 12                        NaN                        NaN
# 13                        1.0            mesial temporal
# 14                        1.0                hippocampus
# 16                        1.0      hippocampal tail/body
# 18                        1.0                hippocampus
# 23                        NaN                        NaN
# 24                        NaN                        NaN
# 25                        NaN                        NaN
# 26                        NaN                        NaN
# 27                        NaN                        NaN
#
#     cceps_run1_home_meds  cceps_run1_pulsewidth  cceps_run1_sz  \
# 0                      1                    300              0
# 1                      1                    300              0
# 2                      1                    300              0
# 3                      1                    300              0
# 4                      1                    300              0
# 5                      1                    300              0
# 9                      0                    300              0
# 10                     0                    300              1
# 11                     0                    300              1
# 12                     1                    300              0
# 13                     1                    300              1
# 14                     1                    500              1
# 16                     1                    500              1
# 18                     1                    500              1
# 23                     1                    500              1
# 24                     1                    500              1
# 25                     1                    500              1
# 26                     1                    500              1
# 27                     1                    500              1
#
#    cceps_run1_szelecs                          cceps_run1_soz_electrodes  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# 5                 NaN                                                NaN
# 9                 NaN                                                NaN
# 10                LB1  LB1, LB2, LB3, LB4, LB5, LC1, LC2, LC3, LC4, L...
# 11                RC1                                 RB1, RB2, RB3, RB4
# 12                NaN                                                NaN
# 13                LG1                            LB1, LB2, LC1, LC2, LC3
# 14                LB5                                 LC1, LC2, LC3, LC4
# 16                LA4  LA1, LA2, LA3, LB1, LB2, LB3, LC1, LC2, LC3, L...
# 18                LC2                       LB1, LB2, LB3, LC1, LC2, LC3
# 23                LB2  LA1, LA2, LA3, LA4, LB1, LB2, LB3, LB4, LC1, L...
# 24                RP2                                                NaN
# 25                RB1                                                RA1
# 26                LB3                                           LB1, LC1
# 27                RB2                                           RC1, RC2
#
#     cceps_run1_seizure_typical  cceps_hfs_done  cceps_hfs_seizure  \
# 0                          NaN             1.0                1.0
# 1                          NaN             1.0                1.0
# 2                          NaN             1.0                1.0
# 3                          NaN             1.0                1.0
# 4                          NaN             1.0                1.0
# 5                          NaN             1.0                1.0
# 9                          NaN             1.0                1.0
# 10                         2.0             2.0                NaN
# 11                         1.0             1.0                2.0
# 12                         NaN             1.0                1.0
# 13                         1.0             2.0                NaN
# 14                         3.0             2.0                NaN
# 16                         1.0             1.0                1.0
# 18                         1.0             1.0                2.0
# 23                         1.0             NaN                NaN
# 24                         3.0             NaN                NaN
# 25                         2.0             NaN                NaN
# 26                         NaN             NaN                NaN
# 27                         3.0             NaN                NaN
#
#    cceps_hfs_stim_elec_sz  cceps_hfs_sz_typical  Unnamed: 16         ieeg_id
# 0                     RB1                   1.0          NaN  HUP211_phaseII
# 1                     LG2                   2.0          NaN  HUP212_phaseII
# 2           LJ1, LJ2, LJ3                   2.0          NaN  HUP213_phaseII
# 3                LB1, RB1                   1.0          NaN  HUP214_phaseII
# 4                     LC1                   1.0          NaN  HUP216_phaseII
# 5                RA1, RB1                   1.0          NaN  HUP218_phaseII
# 9                     LA1                   1.0          NaN  HUP223_phaseII
# 10                    NaN                   NaN          NaN  HUP224_phaseII
# 11                    NaN                   NaN          NaN  HUP225_phaseII
# 12               LB1, RB1                   1.0          NaN  HUP228_phaseII
# 13                    NaN                   NaN          NaN  HUP229_phaseII
# 14                    NaN                   NaN          NaN  HUP230_phaseII
# 16                    LA1                   1.0          NaN  HUP235_phaseII
# 18                    NaN                   NaN          NaN  HUP238_phaseII
# 23                    NaN                   NaN          NaN  HUP246_phaseII
# 24                    NaN                   NaN          NaN  HUP247_phaseII
# 25                    NaN                   NaN          NaN  HUP249_phaseII
# 26                    NaN                   NaN          NaN  HUP250_phaseII
# 27                    NaN                   NaN          NaN  HUP253_phaseII

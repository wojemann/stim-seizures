# %%
import pandas as pd
import json

# %%
metadata = pd.read_csv('metadata.csv')
metadata = metadata[(metadata.cceps_hfs_seizure == 1) | (metadata.cceps_run1_sz == 1)]
metadata.loc[:,'ieeg_id'] = 'HUP' + metadata.hupsubjno.apply(str) + '_phaseII'
len(metadata)
metadata.head()
# Out:
#    record_id       hupsubjno  ageatieegimplant  \
# 0        650  HUP211_phaseII              23.0
# 1        651  HUP212_phaseII              55.0
# 2        649  HUP213_phaseII              21.0
# 3        652  HUP214_phaseII              40.0
# 4        658  HUP216_phaseII              21.0
#
#                          ieeg_ictal_onset_electrodes  \
# 0  LC1, LC2, LI1, LI2, LI3, LI4, LB1, LB2, LC1, L...
# 1                                                NaN
# 2  LA1, LA2, LA3, LA4, LA5, LH3, LH4, LH5, LH6, L...
# 3                                 LB1, LB2, RB1, RB2
# 4                                 LC1, LC2, LB1, LB2
#
#    ieeg_ictal_onset_anat_lat ieeg_ictal_onset_anat_spec  cceps_run1_home_meds  \
# 0                        3.0            mesial temporal                     1
# 1                        NaN                        NaN                     1
# 2                        1.0                 multifocal                     1
# ...
